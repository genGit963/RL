# %%
# !conda install swig
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !pip install "gym[box2d]"
# Out:
# Collecting gym[box2d]
#   Using cached gym-0.26.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.0 in /Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages (from gym[box2d]) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages (from gym[box2d]) (3.0.0)
# Collecting gym-notices>=0.0.4 (from gym[box2d])
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Using cached pygame-2.1.0.tar.gz (5.8 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: swig==4.* in /Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages (from gym[box2d]) (4.1.1)
# Building wheels for collected packages: box2d-py, pygame
#   Building wheel for box2d-py (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [45 lines of output]
#       Using setuptools (version 68.0.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-311
#       creating build/lib.macosx-11.1-arm64-cpython-311/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.macosx-11.1-arm64-cpython-311/Box2D
#       copying library/Box2D/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/Box2D
#       creating build/lib.macosx-11.1-arm64-cpython-311/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       Box2D/Common/b2Math.h:67: Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#       Box2D/Box2D_math.i:47: Warning 302: %extend definition of 'b2Vec2'.
#       Box2D/Common/b2Math.h:158: Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#       Box2D/Box2D_math.i:168: Warning 302: %extend definition of 'b2Vec3'.
#       Box2D/Common/b2Math.h:197: Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#       Box2D/Box2D_math.i:301: Warning 302: %extend definition of 'b2Mat22'.
#       Box2D/Common/b2Math.h:271: Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#       Box2D/Box2D_math.i:372: Warning 302: %extend definition of 'b2Mat33'.
#       Box2D/Collision/b2DynamicTree.h:44: Warning 312: Nested union not currently supported (ignored).
#       Box2D/Common/b2Settings.h:144: Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D/Common/b2Math.h:91: Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D/Common/b2Math.h:85: Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       creating build/temp.macosx-11.1-arm64-cpython-311
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Collision
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Collision/Shapes
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Common
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Dynamics
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Dynamics/Contacts
#       creating build/temp.macosx-11.1-arm64-cpython-311/Box2D/Dynamics/Joints
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/include -arch arm64 -fPIC -O2 -isystem /Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/include -arch arm64 "-I/Users/eudgen/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/include/python3.11" -c Box2D/Box2D_wrap.cpp -o build/temp.macosx-11.1-arm64-cpython-311/Box2D/Box2D_wrap.o -I. -Wno-unused
#       clang: error: no such file or directory: 'Engineering/Artificial'
#       clang: error: no such file or directory: 'Intelligence/Machine'
#       clang: error: no such file or directory: 'Learning/Reinforcement'
#       clang: error: no such file or directory: 'Learning/conda_rl/env/include'
#       clang: error: no such file or directory: 'Engineering/Artificial'
#       clang: error: no such file or directory: 'Intelligence/Machine'
#       clang: error: no such file or directory: 'Learning/Reinforcement'
#       clang: error: no such file or directory: 'Learning/conda_rl/env/include'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
#   Building wheel for pygame (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [17 lines of output]
#       clang: error: no such file or directory: 'Engineering/Artificial'
#       clang: error: no such file or directory: 'Intelligence/Machine'
#       clang: error: no such file or directory: 'Learning/Reinforcement'
#       clang: error: no such file or directory: 'Learning/conda_rl/env/include'
#       clang: error: no such file or directory: 'Engineering/Artificial'
#       clang: error: no such file or directory: 'Intelligence/Machine'
#       clang: error: no such file or directory: 'Learning/Reinforcement'
#       clang: error: no such file or directory: 'Learning/conda_rl/env/include'
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/MacCompile
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pygame
#   Running setup.py clean for pygame
# Failed to build box2d-py pygame
# ERROR: Could not build wheels for box2d-py, pygame, which is required to install pyproject.toml-based projects

# %%
# !pip install 'stable_baselines3[extra]'
# Out:
# Collecting stable_baselines3[extra]
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3[extra])
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from stable_baselines3[extra]) (1.26.0)
# Collecting torch>=1.13 (from stable_baselines3[extra])
#   Downloading torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata (24 kB)
# Collecting cloudpickle (from stable_baselines3[extra])
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pandas in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from stable_baselines3[extra]) (2.1.2)
# Collecting matplotlib (from stable_baselines3[extra])
#   Downloading matplotlib-3.8.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting opencv-python (from stable_baselines3[extra])
#   Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting pygame (from stable_baselines3[extra])
#   Downloading pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting tensorboard>=2.9.1 (from stable_baselines3[extra])
#   Downloading tensorboard-2.15.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: psutil in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from stable_baselines3[extra]) (5.9.0)
# Collecting tqdm (from stable_baselines3[extra])
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 162.3 kB/s eta 0:00:00a 0:00:01
# Collecting rich (from stable_baselines3[extra])
#   Downloading rich-13.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting shimmy~=1.1.0 (from shimmy[atari]~=1.1.0; extra == "extra"->stable_baselines3[extra])
#   Downloading Shimmy-1.1.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow (from stable_baselines3[extra])
#   Downloading Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting click (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra])
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 664.6 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3[extra]) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3[extra])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0; extra == "extra"->stable_baselines3[extra])
#   Downloading ale_py-0.8.1-cp311-cp311-macosx_11_0_arm64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading grpcio-1.59.2-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting protobuf<4.24,>=3.19.6 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting filelock (from torch>=1.13->stable_baselines3[extra])
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch>=1.13->stable_baselines3[extra])
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 2.5 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch>=1.13->stable_baselines3[extra])
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from torch>=1.13->stable_baselines3[extra]) (3.1.2)
# Collecting fsspec (from torch>=1.13->stable_baselines3[extra])
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->stable_baselines3[extra])
#   Downloading contourpy-1.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->stable_baselines3[extra])
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable_baselines3[extra])
#   Downloading fonttools-4.43.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 4.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->stable_baselines3[extra])
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from matplotlib->stable_baselines3[extra]) (23.1)
# Collecting pyparsing>=2.3.1 (from matplotlib->stable_baselines3[extra])
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from matplotlib->stable_baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from pandas->stable_baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from pandas->stable_baselines3[extra]) (2023.3)
# Collecting markdown-it-py>=2.2.0 (from rich->stable_baselines3[extra])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from rich->stable_baselines3[extra]) (2.15.1)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]~=1.1.0; extra == "extra"->stable_baselines3[extra])
#   Downloading importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 7.6 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->stable_baselines3[extra])
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable_baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/eudgen/Documents/ML/conda_ml/env/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.1)
# Collecting mpmath>=0.19 (from sympy->torch>=1.13->stable_baselines3[extra])
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 3.0 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable_baselines3[extra])
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Downloading tensorboard-2.15.0-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.5 MB/s eta 0:00:0000:0100:01m
# Downloading torch-2.1.0-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 4.1 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.8.1-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 4.8 MB/s eta 0:00:0000:0100:01m
# Downloading Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 5.6 MB/s eta 0:00:0000:0100:01
# Downloading pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 5.3 MB/s eta 0:00:0000:0100:01
# Downloading rich-13.6.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.8/239.8 kB 9.7 MB/s eta 0:00:00
# Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.9 MB/s eta 0:00:00
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.2 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp311-cp311-macosx_11_0_arm64.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 8.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.43.1-cp311-cp311-macosx_10_9_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 10.9 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading grpcio-1.59.2-cp311-cp311-macosx_10_10_universal2.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 5.6 MB/s eta 0:00:0000:0100:01m
# Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 4.7 MB/s eta 0:00:00
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 6.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.4 MB/s eta 0:00:00
# Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 7.7 MB/s eta 0:00:00ta 0:00:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 6.8 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 7.2 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 6.9 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.6 MB/s eta 0:00:00a 0:00:01
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=7d8e9a864d62da1b85e9e90e733b5ce660ff06f5d3f85d2d899e76ea4b231dea
#   Stored in directory: /Users/eudgen/Library/Caches/pip/wheels/bc/fc/c6/8aa657c0d2089982f2dabd110efc68c61eb49831fdb7397351
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: mpmath, farama-notifications, werkzeug, tqdm, tensorboard-data-server, sympy, pyparsing, pygame, pyasn1, protobuf, pillow, opencv-python, oauthlib, networkx, mdurl, markdown, kiwisolver, importlib-resources, grpcio, fsspec, fonttools, filelock, cycler, contourpy, cloudpickle, click, cachetools, absl-py, torch, rsa, requests-oauthlib, pyasn1-modules, matplotlib, markdown-it-py, gymnasium, AutoROM.accept-rom-license, autorom, ale-py, stable_baselines3, shimmy, rich, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed AutoROM.accept-rom-license-0.6.1 absl-py-2.0.0 ale-py-0.8.1 autorom-0.6.1 cachetools-5.3.2 click-8.1.7 cloudpickle-3.0.0 contourpy-1.1.1 cycler-0.12.1 farama-notifications-0.0.4 filelock-3.13.1 fonttools-4.43.1 fsspec-2023.10.0 google-auth-2.23.4 google-auth-oauthlib-1.1.0 grpcio-1.59.2 gymnasium-0.29.1 importlib-resources-6.1.0 kiwisolver-1.4.5 markdown-3.5.1 markdown-it-py-3.0.0 matplotlib-3.8.1 mdurl-0.1.2 mpmath-1.3.0 networkx-3.2.1 oauthlib-3.2.2 opencv-python-4.8.1.78 pillow-10.1.0 protobuf-4.23.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 pygame-2.5.2 pyparsing-3.1.1 requests-oauthlib-1.3.1 rich-13.6.0 rsa-4.9 shimmy-1.1.0 stable_baselines3-2.1.0 sympy-1.12 tensorboard-2.15.0 tensorboard-data-server-0.7.2 torch-2.1.0 tqdm-4.66.1 werkzeug-3.0.1

# %%
environment = 'CarRacing-v2'
env = gym.make(environment)
env = DummyVecEnv([lambda:env])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages/gymnasium/envs/box2d/bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[39], line 2
#       1 environment = 'CarRacing-v2'
# ----> 2 env = gym.make(environment)
#       3 env = DummyVecEnv([lambda:env])
#
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages/gymnasium/envs/registration.py:756, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     753     env_creator = env_spec.entry_point
#     754 else:
#     755     # Assume it's a string
# --> 756     env_creator = load_env_creator(env_spec.entry_point)
#     758 # Determine if to use the rendering
#     759 render_modes: list[str] | None = None
#
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages/gymnasium/envs/registration.py:545, in load_env_creator(name)
#     536 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     537
#     538 Args:
#    (...)
#     542     The environment constructor for the given environment name.
#     543 """
#     544 mod_name, attr_name = name.split(":")
# --> 545 mod = importlib.import_module(mod_name)
#     546 fn = getattr(mod, attr_name)
#     547 return fn
#
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages/gymnasium/envs/box2d/__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File ~/Documents/Software Engineering/Artificial Intelligence/Machine Learning/Reinforcement Learning/conda_rl/env/lib/python3.11/site-packages/gymnasium/envs/box2d/bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         "Box2D is not installed, run `pip install gymnasium[box2d]`"
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, run `pip install gymnasium[box2d]`

# %%
# !conda install -c conda-forge gym-box2d
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - gym-box2d -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0']
#
# Your python: python=3.11
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
